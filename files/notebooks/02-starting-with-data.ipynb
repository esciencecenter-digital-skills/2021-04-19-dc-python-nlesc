# %% [markdown]
# # Starting with data
# * How can I import data in Python
# * What is Pandas?
# * Why should I use Pandas to work with data?

# %%
pwd
# Out:
# '/Users/svenvanderburg/projects/teaching/dc-python-april/notebooks'

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from '/Users/svenvanderburg/opt/anaconda3/envs/teaching/lib/python3.7/site-packages/pandas/__init__.py'>

# %%
pd.read_csv("../data/raw/surveys.csv")
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
# Read in species.csv as a dataframe
surveys_df = pd.read_csv("../data/raw/surveys.csv")

# %%
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
type(surveys_df)
# Out:
# pandas.core.frame.DataFrame

# %%
surveys_df.head(6) # Shows the first 6 rows of dataframe
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN

# %% [markdown]
# ## Exploring our data

# %%
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %% [markdown]
# ## Challenge - DataFrames
# Using our DataFrame surveys_df, try out the attributes & methods below to see what they return.
#
# 1. surveys_df.columns
# 2. surveys_df.shape Take note of the output of shape - what format does it return the shape of the DataFrame in?
#
# HINT: More on tuples, [here](https://docs.python.org/3/tutorial/datastructures.html#tuples-and-sequences).
#
# 3. surveys_df.head() Also, what does surveys_df.head(15) do?
# 3. surveys_df.tail()

# %% [markdown]
# ### If you're done:
# Checkout and try other attributes in 'Attributes' section of https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
surveys_df.shape
# Out:
# (35549, 9)

# %%
type(surveys_df.shape)
# Out:
# tuple

# %%
surveys_df.head(15)
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10         11      7   16  1977        5         DS    F             53.0
# 11         12      7   16  1977        7         DM    M             38.0
# ...

# %%
surveys_df.tail(15)
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35534      35535     12   31  2002       14         DM    M             37.0
# 35535      35536     12   31  2002       14         DM    F             35.0
# 35536      35537     12   31  2002       14         DM    F             36.0
# 35537      35538     12   31  2002       15         PB    F             26.0
# 35538      35539     12   31  2002       15         SF    M             26.0
# 35539      35540     12   31  2002       15         PB    F             26.0
# 35540      35541     12   31  2002       15         PB    F             24.0
# 35541      35542     12   31  2002       15         PB    F             26.0
# 35542      35543     12   31  2002       15         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# ...

# %% [markdown]
# ## Calculating Statistics from data

# %%
surveys_df['species_id']
# Out:
# 0         NL
# 1         NL
# 2         DM
# 3         DM
# 4         DM
#         ...
# 35544     AH
# 35545     AH
# 35546     RM
# 35547     DO
# 35548    NaN
# Name: species_id, Length: 35549, dtype: object

# %%
pd.unique(surveys_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
a_list = [1, 2, 3]
len(a_list)
# Out:
# 3

# %%
unique_species = pd.unique(surveys_df['species_id'])

# %%
len(unique_species)
# Out:
# 49

# %%
site_names = pd.unique(surveys_df['plot_id'])

# %%
site_names
# Out:
# array([ 2,  3,  7,  1,  6,  5,  8,  4, 11, 14, 15, 13,  9, 10, 17, 16, 20,
#        23, 18, 21, 22, 19, 12, 24])

# %%
len(site_names)
# Out:
# 24

# %%
surveys_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
surveys_df['weight'].min()
# Out:
# 4.0

# %%
surveys_df['weight'].mean()
surveys_df['weight'].std()
# Out:
# 36.63125947458358

# %% [markdown]
# ## Groups in Pandas

# %%
grouped_data = surveys_df.groupby('sex')

# %%
# summary statistics for all numeric columns by sex
grouped_data.describe()
# Out:
#     record_id                                                               \
#         count          mean           std  min      25%      50%       75%
# sex
# F     15690.0  18036.412046  10423.089000  3.0  8917.50  18075.5  27250.00
# M     17348.0  17754.835601  10132.203323  1.0  8969.75  17727.5  26454.25
#
#                 month            ... hindfoot_length         weight  \
#          max    count      mean  ...             75%   max    count
# sex                              ...
# F    35547.0  15690.0  6.587253  ...            36.0  64.0  15303.0
# M    35548.0  17348.0  6.396184  ...            36.0  58.0  16879.0
#
#
#           mean        std  min   25%   50%   75%    max
# sex
# F    42.170555  36.847958  4.0  20.0  34.0  46.0  274.0
# M    42.995379  36.184981  4.0  20.0  39.0  49.0  280.0
#
# [2 rows x 56 columns]

# %%
grouped_data['weight'].describe()
# Out:
#        count       mean        std  min   25%   50%   75%    max
# sex
# F    15303.0  42.170555  36.847958  4.0  20.0  34.0  46.0  274.0
# M    16879.0  42.995379  36.184981  4.0  20.0  39.0  49.0  280.0

# %% [markdown]
# ## Exercise
# 1. How many recorded individuals are female F and how many male M?
# 2. What happens when you group by two columns using the following syntax and then calculate mean values?
#   * `grouped_data2 = surveys_df.groupby(['plot_id', 'sex'])`
#   * `grouped_data2.mean()`
# 3. Summarize weight values for each site in your data. HINT: you can use the following syntax to only create summary statistics for one column in your data. `by_site['weight'].describe()`

# %%
grouped_data = surveys_df.groupby('sex')

# %%
grouped_data.count()
# Out:
#      record_id  month    day   year  plot_id  species_id  hindfoot_length  \
# sex
# F        15690  15690  15690  15690    15690       15690            14894
# M        17348  17348  17348  17348    17348       17348            16476
#
#      weight
# sex
# F     15303
# M     16879

# %%
grouped_data['record_id'].count()
# Out:
# sex
# F    15690
# M    17348
# Name: record_id, dtype: int64

# %%
type(['plot_id', 'sex'])
# Out:
# list

# %%
grouped_data2 = surveys_df.groupby(['sex', 'plot_id'])
grouped_data2.mean()
# Out:
#                 record_id     month        day         year  hindfoot_length  \
# sex plot_id
# F   1        18390.384434  6.597877  15.338443  1990.933962        31.733911
#     2        17714.753608  6.426804  16.288660  1990.449485        30.161220
#     3        19888.783875  6.610302  15.993281  1992.013438        23.774044
#     4        17489.205275  6.447248  15.608945  1990.235092        33.249102
#     5        12280.793169  6.142315  15.722960  1986.485769        28.921844
#     6        19406.503392  6.640434  15.947083  1991.579376        26.981322
#     7        19069.668657  6.385075  15.313433  1991.441791        19.779553
#     8        18920.276190  6.644048  15.479762  1991.267857        32.187578
#     9        16217.497069  6.507620  15.309496  1989.303634        35.126092
#     10       16001.496454  5.588652  16.964539  1989.248227        18.641791
#     11       16994.962287  6.770073  15.954988  1989.836983        32.029299
# ...

# %%
by_site = surveys_df.groupby('plot_id')

# %%
by_site['weight'].describe()
# Out:
#           count       mean        std  min   25%   50%   75%    max
# plot_id
# 1        1903.0  51.822911  38.176670  4.0  30.0  44.0  53.0  231.0
# 2        2074.0  52.251688  46.503602  5.0  24.0  41.0  50.0  278.0
# 3        1710.0  32.654386  35.641630  4.0  14.0  23.0  36.0  250.0
# 4        1866.0  47.928189  32.886598  4.0  30.0  43.0  50.0  200.0
# 5        1092.0  40.947802  34.086616  5.0  21.0  37.0  48.0  248.0
# 6        1463.0  36.738893  30.648310  5.0  18.0  30.0  45.0  243.0
# 7         638.0  20.663009  21.315325  4.0  11.0  17.0  23.0  235.0
# 8        1781.0  47.758001  33.192194  5.0  26.0  44.0  51.0  178.0
# 9        1811.0  51.432358  33.724726  6.0  36.0  45.0  50.0  275.0
# 10        279.0  18.541219  20.290806  4.0  10.0  12.0  21.0  237.0
# 11       1793.0  43.451757  28.975514  5.0  26.0  42.0  48.0  212.0
# 12       2219.0  49.496169  41.630035  6.0  26.0  42.0  50.0  280.0
# 13       1371.0  40.445660  34.042767  5.0  20.5  33.0  45.0  241.0
# ...

# %%
surveys_df['weight']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN
# Name: weight, Length: 35549, dtype: float64

# %%
surveys_df['weight'] * 2
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 35544      NaN
# 35545      NaN
# 35546     28.0
# 35547    102.0
# 35548      NaN
# Name: weight, Length: 35549, dtype: float64

# %%
a_list = [1, 2, 3]
a_tuple = (1, 2, 3)

a_list[0] # Looking up a value in a list
a_dictitionary['key'] # Looking up a key
print() # Calling a function (with arguments)
surveys_df['weight'] # Looking up data in wegith column
surveys_df.describe() # Calling describe method
