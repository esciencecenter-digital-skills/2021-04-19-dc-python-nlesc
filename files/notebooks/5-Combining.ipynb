# %%
import pandas as pd

# %%
# read the data
surveys_df = pd.read_csv('../data/raw/surveys.csv')

# %%
surveys_first10 = surveys_df.head(10)
surveys_first10
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN

# %%
surveys_last10 = surveys_df.tail(10)
surveys_last10
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35539      35540     12   31  2002       15         PB    F             26.0
# 35540      35541     12   31  2002       15         PB    F             24.0
# 35541      35542     12   31  2002       15         PB    F             26.0
# 35542      35543     12   31  2002       15         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35539    23.0
# 35540    31.0
# 35541    29.0
# 35542    34.0
# 35543     NaN
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
vertical_stacked = pd.concat([surveys_first10, surveys_last10], axis=0)

# %%
vertical_stacked
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 5              6      7   16  1977        1         PF    M             14.0
# 6              7      7   16  1977        2         PE    F              NaN
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# 9             10      7   16  1977        6         PF    F             20.0
# 35539      35540     12   31  2002       15         PB    F             26.0
# 35540      35541     12   31  2002       15         PB    F             24.0
# 35541      35542     12   31  2002       15         PB    F             26.0
# 35542      35543     12   31  2002       15         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 35539    23.0
# 35540    31.0
# 35541    29.0
# 35542    34.0
# 35543     NaN
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
# create a nice new index, drop the weird index
vertical_stacked.reset_index(drop=True)
# Out:
#     record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10      35540     12   31  2002       15         PB    F             26.0
# 11      35541     12   31  2002       15         PB    F             24.0
# 12      35542     12   31  2002       15         PB    F             26.0
# 13      35543     12   31  2002       15         PB    F             27.0
# 14      35544     12   31  2002       15         US  NaN              NaN
# 15      35545     12   31  2002       15         AH  NaN              NaN
# 16      35546     12   31  2002       15         AH  NaN              NaN
# 17      35547     12   31  2002       10         RM    F             15.0
# 18      35548     12   31  2002        7         DO    M             36.0
# 19      35549     12   31  2002        5        NaN  NaN              NaN
#
#     weight
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10    23.0
# 11    31.0
# 12    29.0
# 13    34.0
# 14     NaN
# 15     NaN
# 16     NaN
# 17    14.0
# 18    51.0
# 19     NaN

# %%
# Create two artificial dataframes
surveys_sub1 = surveys_df[['record_id', 'month', 'day', 'year']]
surveys_sub2 = surveys_df[['plot_id', 'species_id']]

# %%
print(surveys_sub1.shape)
print(surveys_sub2.shape)
# Out:
# (35549, 4)
# (35549, 2)

# %%
horizontal_stack = pd.concat([surveys_sub1, surveys_sub2], axis=1)
horizontal_stack.head()
# Out:
#    record_id  month  day  year  plot_id species_id
# 0          1      7   16  1977        2         NL
# 1          2      7   16  1977        3         NL
# 2          3      7   16  1977        2         DM
# 3          4      7   16  1977        7         DM
# 4          5      7   16  1977        3         DM

# %% [markdown]
# ## Exercise:
# In the data folder, there are two survey data files: surveys2001.csv and surveys2002.csv.
# 1. Read the data into Python and combine the files to make one new data frame.
# 2. (optional) Create a plot of average plot weight by year grouped by sex.
# 3. (optional) Export your results as a CSV and make sure it reads back into Python properly.

# %%
# Read the data
surveys2001 = pd.read_csv('../data/raw/surveys2001.csv')
surveys2002 = pd.read_csv('../data/raw/surveys2002.csv')

# %%
print(surveys2001.shape)
print(surveys2002.shape)
# Out:
# (1434, 10)
# (2078, 10)

# %%
print(surveys2001.columns)
print(surveys2002.columns)
# Out:
# Index(['Unnamed: 0', 'record_id', 'month', 'day', 'year', 'site_id',
#        'species_id', 'sex', 'hindfoot_length', 'weight'],
#       dtype='object')
# Index(['Unnamed: 0', 'record_id', 'month', 'day', 'year', 'site_id',
#        'species_id', 'sex', 'hindfoot_length', 'weight'],
#       dtype='object')

# %%
# Vertical stacking
surveys_2001_2002 = pd.concat([surveys2001, surveys2002], axis=0)
surveys_2001_2002.shape
# Out:
# (3512, 10)

# %%
# make nice index
surveys_2001_2002 = surveys_2001_2002.reset_index(drop=True)
surveys_2001_2002.head()
# Out:
#    Unnamed: 0  record_id  month  day  year  site_id species_id sex  \
# 0       31710      31711      1   21  2001        1         PB   F
# 1       31711      31712      1   21  2001        1         DM   M
# 2       31712      31713      1   21  2001        1         PB   M
# 3       31713      31714      1   21  2001        1         DO   M
# 4       31714      31715      1   21  2001        2         OT   M
#
#    hindfoot_length  weight
# 0             26.0    25.0
# 1             37.0    43.0
# 2             29.0    44.0
# 3             34.0    53.0
# 4             20.0    27.0

# %%
grouped_20012002 = surveys_2001_2002.groupby(['sex', 'year'])

# %%
mean_weight = grouped_20012002['weight'].mean()
mean_weight
# Out:
# sex  year
# F    2001    36.034771
#      2002    33.878761
# M    2001    36.404196
#      2002    37.490506
# Name: weight, dtype: float64

# %%
mean_weight.unstack().plot(kind='bar', stacked=True)

# %% [markdown]
# ## Joining tables

# %%
# import species information
species_df = pd.read_csv('../data/raw/species.csv')
species_df.head()
# Out:
#   species_id             genus          species    taxa
# 0         AB        Amphispiza        bilineata    Bird
# 1         AH  Ammospermophilus          harrisi  Rodent
# 2         AS        Ammodramus       savannarum    Bird
# 3         BA           Baiomys          taylori  Rodent
# 4         CB   Campylorhynchus  brunneicapillus    Bird

# %%
# Take smaller subset for demonstration purposes
species_sub = pd.read_csv('../data/raw/speciesSubset.csv')
surveys_sub = surveys_df.head(10)

# %%
print(species_sub.shape)
print(surveys_sub.shape)
# Out:
# (3, 4)
# (10, 9)

# %%
species_sub
# Out:
#   species_id       genus   species    taxa
# 0         DM   Dipodomys  merriami  Rodent
# 1         NL     Neotoma  albigula  Rodent
# 2         PE  Peromyscus  eremicus  Rodent

# %%
surveys_sub
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN

# %%
# Inner join: only take species-ids that exists in both tables
merged = pd.merge(left=surveys_sub, right=species_sub, left_on='species_id', right_on='species_id')
merged
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          8      7   16  1977        1         DM   M             37.0
# 6          9      7   16  1977        1         DM   F             34.0
# 7          7      7   16  1977        2         PE   F              NaN
#
#    weight       genus   species    taxa
# 0     NaN     Neotoma  albigula  Rodent
# 1     NaN     Neotoma  albigula  Rodent
# 2     NaN   Dipodomys  merriami  Rodent
# 3     NaN   Dipodomys  merriami  Rodent
# 4     NaN   Dipodomys  merriami  Rodent
# 5     NaN   Dipodomys  merriami  Rodent
# 6     NaN   Dipodomys  merriami  Rodent
# 7     NaN  Peromyscus  eremicus  Rodent

# %%
# Left join: keep all rows from the left table
merged_left = pd.merge(left=surveys_sub, right=species_sub, left_on='species_id', right_on='species_id', how='left')
merged_left
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight       genus   species    taxa
# 0     NaN     Neotoma  albigula  Rodent
# 1     NaN     Neotoma  albigula  Rodent
# 2     NaN   Dipodomys  merriami  Rodent
# 3     NaN   Dipodomys  merriami  Rodent
# 4     NaN   Dipodomys  merriami  Rodent
# 5     NaN         NaN       NaN     NaN
# 6     NaN  Peromyscus  eremicus  Rodent
# 7     NaN   Dipodomys  merriami  Rodent
# 8     NaN   Dipodomys  merriami  Rodent
# 9     NaN         NaN       NaN     NaN

# %%
# We do an inner join for all data:
merged_total = pd.merge(left=surveys_df, right=species_df, left_on='species_id', right_on='species_id', how='inner')
merged_total.shape
# Out:
# (34786, 12)

# %%
taxa_per_plotid = merged_total.groupby(['plot_id', 'taxa'])['record_id'].count()
taxa_per_plotid.head()
# Out:
# plot_id  taxa
# 1        Bird        11
#          Rabbit       2
#          Rodent    1976
# 2        Bird        17
#          Rabbit       3
# Name: record_id, dtype: int64

# %%
taxa_per_plotid.unstack().plot(kind='bar', stacked=True)

# %%
taxa_per_sex_per_plotid = merged_total.groupby(['plot_id', 'taxa', 'sex'])['record_id'].count()
taxa_per_sex_per_plotid.head()
# Out:
# plot_id  taxa    sex
# 1        Rodent  F       848
#                  M      1095
# 2        Rodent  F       970
#                  M      1144
# 3        Rodent  F       893
# Name: record_id, dtype: int64

# %%
taxa_per_sex_per_plotid.unstack().plot(kind='bar', stacked=True)

# %%
merged_copy = merged_total.copy()
merged_copy['sex'] = merged_copy['sex'].fillna('x')

# %%
taxa_per_sex_per_plotid = merged_copy.groupby(['plot_id', 'taxa', 'sex'])['record_id'].count()
taxa_per_sex_per_plotid.unstack().plot(kind='bar', stacked=True)
